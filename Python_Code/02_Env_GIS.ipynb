# %%
print("Hello")

# %%
radius = 10
pi = 3.14
area = radius *pi**2
print(area)

# %%
radius = 10
pi = 3.14
radius = 20

print("radius =", radius)
print("pi =", pi)

# %%
radius, pi = 10, 3.14

# %%
x = 10
y = 3.14
name = "Seoul"
is_valid = True

print(type(x))
print(type(y))
print(type(name))
print(type(is_valid))

# %%
print(10 + 5)
print("10" + "5")
print(10 + "5")

# %%
print(10 + 5)
print("10" + "5")
#print(10 + "5")

# %%
x = 7; y = 6
print(x + y)

x = '7'; y = '6'
print(x + y)

x = 7; y = 6
print(x + y+x)

x = '7'; y = '6'
print(x + y+ x)

# %%
text1 = "Hello"
text2 = "Hello World"
text3 = "Hello World'
text4 = 'Hello World"

# %%
x = hello

# %%
message1 = "I'm learning python"
message2 = 'He said, "Hello!"'

print(message1)
print(message2)

# %%
message = 'I\'m learning Python'
print(message)

# %%
print("Hello\t Python")
print("Name\tScore")
print("C:\\Data\\GIS")
