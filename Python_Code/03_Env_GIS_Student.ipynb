# %% [markdown]
# # Week 3: Environmental GIS — Student Practice
#
# Complete the **10 blanks** marked `____` in Q01–Q10. Replace each marker with the required Python code.
# Use the comments and surrounding examples as hints. Complete each blank before running that cell, then run the cells in order.
# Some cells will produce an error until their blanks are completed.

# %%
num_features = 500 # Number of features in the geospatial dataset

# %%
latitude = 35.6895 # Latitude of a location on the Earth's surface
longitude = 139.6917 # Longitude of a location on the Earth's surface

# %%
coordinate_system = "WGS 84" # Commonly used coordinate reference system

# %%
is_georeferenced = True # Indicates whether the dataset is georeferenced

# %%
coordinates = [
35.6895,
139.6917,
]

# %%
feature_attributes = {
"name": "Mount Fuji",
"height_meters": 3776,
"type": "Stratovolcano",
"location": [35.3606, 138.7274],
} # Dictionary containing the attributes of a geographic feature

# %%
num_features += 20 # num_features = num_features + 20
print("Updated number of features:", num_features)

# %%
# Q01: Convert latitude from degrees to radians.
import math
latitude = 35.6895
latitude_radians = math.____(latitude)
print("Latitude in radians:", latitude_radians)

# %%
# Q02: Add a new value to the end of the list.
coordinates = [35.6895, 139.6917]
coordinates.____(34.0522) # Add the latitude of Los Angeles
coordinates.append(-118.2437) # Add the longitude of Los Angeles
print("Updated coordinates:", coordinates)

# %%
mount_fuji_name = feature_attributes["name"]
mount_fuji_height = feature_attributes["height_meters"]
print(f"{mount_fuji_name} is {mount_fuji_height} meters high.")

# %%
city_name = "San Francisco"
# Convert to lowercase
city_lowercase = city_name.lower()
print("Lowercase:", city_lowercase)
# Convert to uppercase
city_uppercase = city_name.upper()
print("Uppercase:", city_uppercase)
# Convert to title case (capitalize the first letter of each word)
city_title = city_name.title()
print("Title case:", city_title)

# %%
original_city = "San Francisco"
new_city = original_city.replace("San", "Los")
print("Original:", original_city)
print("Modified:", new_city)

# %%
# Q03: Remove spaces from both ends of the string.
location_data = " Mount Everest "
# Remove leading and trailing spaces
clean_location = location_data.____()
print("Cleaned:", clean_location)

# %%
# Coordinates of Seoul: latitude and longitude
seoul_point = (37.5665, 126.9780)
print(f"Seoul coordinates: {seoul_point}")

# %%
# Q04: Select the second element of the tuple.
latitude = seoul_point[0]
longitude = seoul_point[____]
print(f"Latitude: {latitude}")
print(f"Longitude: {longitude}")

# %%
lat, lon = seoul_point # Unpack the tuple into two variables
print(f"Seoul is located at {lat}°N, {lon}°E")

# %%
# Represent various geographic locations as tuples
new_york = (40.7128, -74.0060)
london = (51.5074, -0.1278)
sydney = (-33.8688, 151.2093)
print(f"New York: {new_york}")
print(f"London: {london}")
print(f"Sydney: {sydney}")

# %%
# List of coordinate tuples representing a travel route
route = [
(35.6895, 139.6917), # Tokyo
(34.0522, -118.2437), # Los Angeles
(51.5074, -0.1278), # London
]
print("Travel route:", route)

# %%
# List of elevation measurements (in meters)
elevations = [120.5, 135.2, 150.8, 168.3, 185.7, 203.1]
print("Elevation profile:", elevations)

# %%
# List of city names
cities = ["Tokyo", "Los Angeles", "London", "Paris"]
print("Cities to visit:", cities)

# %%
# Add Paris to the travel route
route.append((48.8566, 2.3522)) # Add the coordinate of Paris
print("Updated route:", route)

# %%
# Add a new elevation measurement
elevations.append(221.4)
print("Updated elevations:", elevations)

# %%
# Access the first city in the route
first_stop = route[0]
print(f"First stop: {first_stop}")
# Access the last city using a negative index
last_stop = route[-1]
print(f"Last stop: {last_stop}")

# %%
# Q05: Use a slice to select the first two stops.
# Get the first two stops on the route
first_two_stops = route[____]
print("First two stops:", first_two_stops)
# Get the middle portion of the elevation data
middle_elevations = elevations[2:5]
print("Middle elevation readings:", middle_elevations)

# %%
# Q06: Write an expression for the mean elevation.
# Count the number of waypoints in the route
num_waypoints = len(route)
print(f"Number of waypoints: {num_waypoints}")

# Find the maximum elevation
max_elevation = max(elevations)
print(f"Highest elevation: {max_elevation} meters")

# Calculate the average elevation
avg_elevation = ____
print(f"Average elevation: {avg_elevation:.1f} meters")

# %%
# Create a set of geographic regions
regions_visited = {"North America", "Europe", "Asia"}
print("Regions visited:", regions_visited)

# %%
# Q07: Convert the list to a collection of unique values.
# Create a set from a list (duplicates are automatically removed)
country_codes = ["US", "CA", "MX", "US", "CA"] # Note the duplicates
unique_codes = ____(country_codes)
print("Original list:", country_codes)
print("Unique country codes:", unique_codes)

# %%
# Create a set of CRS codes
crs_codes = {"EPSG:4326", "EPSG:3857", "EPSG:32633"}
print("Coordinate reference systems:", crs_codes)

# %%
regions_visited = {"North America", "Europe", "Asia"}

# %%
# Add a new region
print("Original set:", regions_visited)
regions_visited.add("Africa")
print("After adding Africa:", regions_visited)
# Try to add a duplicate region
regions_visited.add("Europe") # This does not change the set
print("After trying to add Europe again:", regions_visited)

# %%
# Q08: Find the species shared by both survey areas.
# Two different survey areas with observed species
area_a_species = {"oak", "pine", "maple", "birch"}
area_b_species = {"pine", "birch", "cedar", "fir"}
print("Species in Area A:", area_a_species)
print("Species in Area B:", area_b_species)

# Find species common to both areas
common_species = area_a_species.____(area_b_species)
print("Species found in both areas:", common_species)

# Find species found only in Area A
unique_to_a = area_a_species - area_b_species
print("Species only in Area A:", unique_to_a)

# Find species present in either area (or both)
all_species = area_a_species.union(area_b_species)
print("All species found:", all_species)

# %%
# Dictionary storing city attributes
tokyo_info = {
    "name": "Tokyo",
    "population": 13929286,
    "coordinates": (35.6895, 139.6917),
    "country": "Japan",
    "established": 1603,
}

print("Tokyo information:", tokyo_info)

# %%
# Dictionary for a geographic survey point
survey_point = {
    "point_id": "SP001",
    "latitude": 40.7589,
    "longitude": -73.9851,
    "elevation": 87.3,
    "land_cover": "urban",
    "date_surveyed": "2023-06-15",
}

print("Survey point data:", survey_point)

# %%
# Access specific information about Tokyo
city_name = tokyo_info["name"]
city_population = tokyo_info["population"]
city_coords = tokyo_info["coordinates"]

print(f"City: {city_name}")
print(f"Population: {city_population:,}")
print(f"Coordinates: {city_coords}")

# %%
# Q09: Retrieve a value safely, with a default for a missing key.
# Safely access dictionary values
area = tokyo_info.____("area_km2", "Not specified")
timezone = tokyo_info.get("timezone", "Unknown")

print(f"Area: {area}")
print(f"Timezone: {timezone}")

# %%
# Add new information to the Tokyo dictionary
tokyo_info["area_km2"] = 2191
tokyo_info["timezone"] = "JST"
tokyo_info["population"] = 14000000  # Update the population

print("Updated Tokyo info:", tokyo_info)

# %%
# Q10: Use the appropriate string key to access the entry for France.
# Collection of world capitals
world_capitals = {
    "Japan": {
        "capital": "Tokyo",
        "coordinates": (35.6895, 139.6917),
        "population": 13929286,
    },
    "France": {
        "capital": "Paris",
        "coordinates": (48.8566, 2.3522),
        "population": 2161000,
    },
    "UK": {
        "capital": "London",
        "coordinates": (51.5074, -0.1278),
        "population": 8982000,
    },
}

# Access information about the capital of France
france_info = world_capitals[____]

print(f"France's capital: {france_info['capital']}")
print(f"Population: {france_info['population']:,}")

# %%
# Explore the structure of the Tokyo dictionary
print("Keys in tokyo_info:", list(tokyo_info.keys()))
print("Values in tokyo_info:", list(tokyo_info.values()))

# Check whether a key exists
if "coordinates" in tokyo_info:
    print("Coordinate information is available")

# Retrieve all countries from the capital dictionary
countries = list(world_capitals.keys())
print("Countries in our database:", countries)

# %%
# GPS waypoint with comprehensive metadata
waypoint = {
    "id": "WP001",
    "name": "Trail Start",
    "latitude": 45.3311,
    "longitude": -121.7113,
    "elevation": 1200,
    "description": "Beginning of Pacific Crest Trail section",
    "waypoint_type": "trailhead",
    "facilities": ["parking", "restrooms", "water"],
    "difficulty": "easy",
}

print(f"Waypoint: {waypoint['name']}")
print(
    f"Location: {waypoint['latitude']}, "
    f"{waypoint['longitude']}"
)
print(f"Elevation: {waypoint['elevation']} meters")
print(
    f"Available facilities: "
    f"{', '.join(waypoint['facilities'])}"
)
